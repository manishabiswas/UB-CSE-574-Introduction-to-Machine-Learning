# %% [markdown]
# #### Loading Dependencies

# %%
# %%time
from __future__ import print_function, division, unicode_literals, absolute_import

import os
os.environ["PYTHONHASHSEED"] = str(1)

import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"
import seaborn as sns
sns.set_style('whitegrid')
sns.set_palette('muted')
sns.set_context("notebook", font_scale=1.5,
               rc={"lines.linewidth": 2.5})

from sklearn.model_selection import train_test_split

import warnings 
warnings.filterwarnings("ignore")

# %reload_ext tensorboard
import time

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPool2D

random.seed(1)
np.random.seed(1)
# Out:
# Wall time: 4.89 s

# %% [markdown]
# #### Loading Fashion MNIST Dataset

# %%
import util_mnist_reader
X_train, y_train = util_mnist_reader.load_mnist("data/fashion/", kind='train')
X_test, y_test = util_mnist_reader.load_mnist("data/fashion/", kind='t10k')

# %% [markdown]
# #### Normalizing the data using min-max scalar

# %%
X_train, X_test = X_train/255., X_test/255.

# %%
X_train, X_test = X_train.reshape(-1, 28*28), X_test.reshape(-1, 28*28)

# %% [markdown]
# #### Defining the labels

# %%
labels = [ "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal",	"Shirt", "Sneaker", "Bag", "Ankle boot"]

# %% [markdown]
# #### Spltting data into train and validation

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2)

# %% [markdown]
# #### Defining the helper functions

# %%
def forward(X, W1, b1, W2, b2):
    Z = np.tanh(X.dot(W1) + b1)
    A = Z.dot(W2) + b2
    expA = np.exp(A)
    Y = expA / expA.sum(axis=1, keepdims=True)
    return Y, Z

def classification_rate(Y, P):
    n_correct = 0
    n_total = 0
    for i in range(len(Y)):
        n_total += 1
        if Y[i] == P[i]:
            n_correct += 1
    return float(n_correct) / n_total


def derivative_w2(Z, T, Y):
    N, K = T.shape
    M = Z.shape[1] 
    ret4 = Z.T.dot(T - Y)
    return ret4


def derivative_w1(X, Z, T, Y, W2):
    N, D = X.shape
    M, K = W2.shape
    dZ = (T - Y).dot(W2.T) * (1 - np.power(Z, 2))
    ret2 = X.T.dot(dZ)
    return ret2


def derivative_b2(T, Y):
    return (T - Y).sum(axis=0)


def derivative_b1(T, Y, W2, Z):
    return ((T - Y).dot(W2.T) * (1 - np.power(Z, 2))).sum(axis=0)


def cost(T, Y):
    m = T.shape[0]
    #tot = (T * np.log(Y) 
    tot= - (1/ m)*(np.multiply(T, np.log(Y)))
                             
    return np.sum(tot)

# %% [markdown]
# #### Visualizing the Fashion MNIST Dataset

# %%
def vizualize_fmnist(X, y):
    X = X.reshape(-1,28,28)
    plt.figure(figsize=(20,18))    
    for e in range(36):
        plt.subplot(6, 6, e+1)
        idx = random.randint(0, len(y))
        plt.imshow(X[idx, :, :], cmap="gray", interpolation="nearest")
        plt.grid(True)
        plt.xticks([])
        plt.yticks([])
        plt.title(labels[y[idx]],fontsize=14)
    plt.suptitle("Fashion MNIST Dataset",fontsize=15)
    plt.show()

# %%
vizualize_fmnist(X_train, y_train)

# %% [markdown]
# #### Checking the dimension of Train, Test and Validation Data

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
print(X_val.shape)
# Out:
# (48000, 784)
# (48000,)
# (10000, 784)
# (10000,)
# (12000, 784)

# %%
def vizualize_loss_accuracy(training_dict):
    training_keys = list(training_dict.keys())
    plt.figure(figsize=(18,16))
    for idx in range(len(training_keys)):
        plt.subplot(2,2,1)
        plt.plot(training_dict[training_keys[idx]][0], label = f"Hidden neurons {training_keys[idx]}")
        plt.legend()
        plt.xlabel("Epochs")
        plt.ylabel("Training Loss")

        plt.subplot(2,2,2)
        plt.plot(training_dict[training_keys[idx]][1], label = f"Hidden neurons {training_keys[idx]}")
        plt.legend()
        plt.xlabel("Epochs")
        plt.ylabel("Validation Loss")

        plt.subplot(2,2,3)
        plt.plot(training_dict[training_keys[idx]][2], label = f"Hidden neurons {training_keys[idx]}")
        plt.legend()
        plt.xlabel("Epochs")
        plt.ylabel("Training Accuracy")

        plt.subplot(2,2,4)
        plt.plot(training_dict[training_keys[idx]][3], label = f"Hidden neurons {training_keys[idx]}")
        plt.legend()
        plt.xlabel("Epochs")
        plt.ylabel("Validation Accuracy")

        plt.tight_layout()

# %% [markdown]
# #### Training the Single Neural Network

# %%
def main(X_train, y_train, X_val, y_val):
    D = 784 
    size = [10, 20, 30, 40] 
    K = 10 

    X = X_train[:20000, :]
    Y = y_train[:20000]
    
    #X = X_train
    #Y = y_train
    
    N = len(Y)
    N_val = len(y_val)
    
    T = np.zeros((N, K))
    T_val = np.zeros((N_val, K))
    
    for i in range(N):
        T[i, Y[i]] = 1
    
    for i in range(N_val):
        T_val[i, y_val[i]] = 1

    learning_rate = 1e-4
    

    training_dict = {}
    parameters_dict = {}    

    for M in size:
        W1 = np.random.randn(D, M)
        b1 = np.random.randn(M)
        W2 = np.random.randn(M, K)
        b2 = np.random.randn(K)

        train_costs = []
        validation_costs = []
        train_accuracy = []
        validation_accuracy = []
        
        print(f"\nTraining with {M} number of hidden nodes.")
        
        for epoch in range(0,1000+1):
            output, hidden = forward(X, W1, b1, W2, b2)
            if epoch % 10 == 0:
                
                c = cost(T, output)
                P = np.argmax(output, axis=1)
                r = classification_rate(Y, P)
                
                train_accuracy.append(r)
                train_costs.append(c)
                
                output_val, hidden_val = forward(X_val, W1, b1, W2, b2)
                c_val = cost(T_val, output_val)
                validation_costs.append(c_val)
                predictions_val = np.argmax(output_val, axis=1)
                r_val = classification_rate(y_val, predictions_val)
                validation_accuracy.append(r_val)
                
                if epoch % 100 == 0:
                    print("Training Cost {:.3f} : Training Accuracy {:.2f}% : Validation Cost {:.3f} : Validation Accuracy {:.2f}%".format(c, r*100, c_val, r_val*100))
 
            W2 += learning_rate * derivative_w2(hidden, T, output)
            b2 += learning_rate * derivative_b2(T, output)
            W1 += learning_rate * derivative_w1(X, hidden, T, output, W2)
            b1 += learning_rate * derivative_b1(T, output, W2, hidden)

        parameters_dict[M] = {
            "W2":W2,
            "b2":b2,
            "W1":W1,
            "b1":b1
        }
        
        training_dict[M] = (train_costs, validation_costs, train_accuracy, validation_accuracy)

    return parameters_dict, training_dict

# %%
if __name__ == '__main__':
    parameters_dict, training_dict = main(X_train, y_train, X_val, y_val)
# Out:
# Training with 10 number of hidden nodes.
# Training Cost 7.624 : Training Accuracy 3.32% : Validation Cost 7.621 : Validation Accuracy 3.60%
# Training Cost 1.017 : Training Accuracy 60.72% : Validation Cost 1.025 : Validation Accuracy 60.25%
# Training Cost 0.885 : Training Accuracy 67.77% : Validation Cost 0.907 : Validation Accuracy 66.88%
# Training Cost 0.794 : Training Accuracy 72.26% : Validation Cost 0.827 : Validation Accuracy 71.38%
# Training Cost 0.740 : Training Accuracy 74.28% : Validation Cost 0.782 : Validation Accuracy 72.97%
# Training Cost 0.707 : Training Accuracy 75.19% : Validation Cost 0.754 : Validation Accuracy 73.71%
# Training Cost 0.684 : Training Accuracy 76.08% : Validation Cost 0.736 : Validation Accuracy 74.48%
# Training Cost 0.664 : Training Accuracy 76.77% : Validation Cost 0.722 : Validation Accuracy 75.09%
# Training Cost 0.650 : Training Accuracy 77.23% : Validation Cost 0.713 : Validation Accuracy 75.37%
# Training Cost 0.635 : Training Accuracy 77.74% : Validation Cost 0.702 : Validation Accuracy 75.75%
# Training Cost 0.621 : Training Accuracy 78.25% : Validation Cost 0.693 : Validation Accuracy 76.18%
#
# Training with 20 number of hidden nodes.
# Training Cost 7.350 : Training Accuracy 10.54% : Validation Cost 7.388 : Validation Accuracy 10.25%
# Training Cost 1.321 : Training Accuracy 66.06% : Validation Cost 1.365 : Validation Accuracy 65.33%
# Training Cost 1.036 : Training Accuracy 69.77% : Validation Cost 1.090 : Validation Accuracy 68.88%
# Training Cost 0.974 : Training Accuracy 70.45% : Validation Cost 1.015 : Validation Accuracy 69.76%
# Training Cost 0.928 : Training Accuracy 71.17% : Validation Cost 0.971 : Validation Accuracy 69.96%
# Training Cost 0.878 : Training Accuracy 73.37% : Validation Cost 0.929 : Validation Accuracy 71.41%
# Training Cost 0.839 : Training Accuracy 74.43% : Validation Cost 0.897 : Validation Accuracy 72.24%
# Training Cost 0.810 : Training Accuracy 75.15% : Validation Cost 0.877 : Validation Accuracy 72.84%
# Training Cost 0.786 : Training Accuracy 76.79% : Validation Cost 0.859 : Validation Accuracy 74.46%
# Training Cost 0.761 : Training Accuracy 77.00% : Validation Cost 0.842 : Validation Accuracy 74.92%
# Training Cost 0.709 : Training Accuracy 78.29% : Validation Cost 0.795 : Validation Accuracy 75.85%
#
# Training with 30 number of hidden nodes.
# Training Cost 9.422 : Training Accuracy 7.46% : Validation Cost 9.353 : Validation Accuracy 8.13%
# Training Cost 2.103 : Training Accuracy 67.51% : Validation Cost 2.163 : Validation Accuracy 66.29%
# Training Cost 1.366 : Training Accuracy 62.30% : Validation Cost 1.426 : Validation Accuracy 61.26%
# Training Cost 1.684 : Training Accuracy 69.78% : Validation Cost 1.749 : Validation Accuracy 68.21%
# Training Cost 2.496 : Training Accuracy 70.45% : Validation Cost 2.580 : Validation Accuracy 68.71%
# Training Cost 1.584 : Training Accuracy 63.26% : Validation Cost 1.621 : Validation Accuracy 62.29%
# Training Cost 2.299 : Training Accuracy 72.37% : Validation Cost 2.402 : Validation Accuracy 70.18%
# Training Cost 1.335 : Training Accuracy 72.30% : Validation Cost 1.449 : Validation Accuracy 70.20%
# Training Cost 1.074 : Training Accuracy 69.62% : Validation Cost 1.132 : Validation Accuracy 67.73%
# Training Cost 0.880 : Training Accuracy 74.01% : Validation Cost 0.947 : Validation Accuracy 72.03%
# Training Cost 1.765 : Training Accuracy 79.08% : Validation Cost 1.878 : Validation Accuracy 76.54%
#
# Training with 40 number of hidden nodes.
# Training Cost 12.939 : Training Accuracy 9.72% : Validation Cost 12.961 : Validation Accuracy 9.99%
# Training Cost 2.732 : Training Accuracy 68.01% : Validation Cost 2.847 : Validation Accuracy 66.67%
# Training Cost 2.024 : Training Accuracy 62.23% : Validation Cost 2.128 : Validation Accuracy 60.92%
# Training Cost 1.096 : Training Accuracy 71.45% : Validation Cost 1.197 : Validation Accuracy 69.38%
# Training Cost 1.698 : Training Accuracy 73.33% : Validation Cost 1.776 : Validation Accuracy 71.39%
# Training Cost 1.442 : Training Accuracy 71.27% : Validation Cost 1.521 : Validation Accuracy 69.35%
# Training Cost 1.498 : Training Accuracy 67.73% : Validation Cost 1.652 : Validation Accuracy 65.62%
# Training Cost 1.359 : Training Accuracy 72.49% : Validation Cost 1.524 : Validation Accuracy 70.09%
# Training Cost 1.191 : Training Accuracy 76.50% : Validation Cost 1.377 : Validation Accuracy 73.43%
# Training Cost 1.012 : Training Accuracy 78.42% : Validation Cost 1.141 : Validation Accuracy 75.96%
# Training Cost 1.057 : Training Accuracy 78.89% : Validation Cost 1.239 : Validation Accuracy 75.55%

# %% [markdown]
# #### Visualizing the Training Loss, Validation Loss, Training Accuracy, Validation Accuracy

# %%
vizualize_loss_accuracy(training_dict)

# %% [markdown]
# ### Inference

# %% [markdown]
# #### Loading the Test Data

# %%
print(X_test.shape)
# Out:
# (10000, 784)

# %% [markdown]
# #### Recalling the Trained Parameters

# %%
W1 = parameters_dict[40]["W1"]
b1 = parameters_dict[40]["b1"]
W2 = parameters_dict[40]["W2"]
b2 = parameters_dict[40]["b2"]

# %% [markdown]
# #### Predicting through Forward Neural Network

# %%
output, hidden = forward(X_test, W1, b1, W2, b2)

# %%
predictions = np.argmax(output, axis=1)

# %% [markdown]
# #### Plotting the Predictions

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap=plt.cm.binary)
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'
    plt.xlabel("{} {:2.0f}% ({})".format(labels[predicted_label],
                                100*np.max(predictions_array),
                                labels[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
num_rows = 4
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(20, 15))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, output[i], y_test, X_test.reshape(-1, 28, 28))
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, output[i], y_test)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Classification Accuracy

# %%
P = np.argmax(output, axis=1)
print(f"The accuracy of Shallow Neural Network with 40 hidden nodes is {np.round(classification_rate(y_test, P)*100)}%")
# Out:
# The accuracy of Shallow Neural Network with 40 hidden nodes is 69.0%

# %% [markdown]
# #### Plotting and analyzing other Metrics

# %% [markdown]
# #### Confusion Matrix

# %%
from sklearn.metrics import *
cm = confusion_matrix(y_test, P)
plt.figure(figsize=(12,10))
sns.heatmap(cm, center=0, annot=True, fmt=".0f",linewidths=1, cmap="RdBu",xticklabels=labels,yticklabels=labels)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5]),
#  <a list of 10 Text yticklabel objects>)

# %% [markdown]
# #### Calculating the value of Precision, Recall, Accuracy and F1 score

# %%
print(classification_report(y_test, P, labels=np.unique(y_test).sort()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.24      0.38      1000
#            1       0.97      0.94      0.95      1000
#            2       0.69      0.57      0.62      1000
#            3       0.84      0.81      0.82      1000
#            4       0.00      0.00      0.00      1000
#            5       0.91      0.87      0.89      1000
#            6       0.27      0.84      0.41      1000
#            7       0.88      0.84      0.86      1000
#            8       0.94      0.86      0.90      1000
#            9       0.86      0.93      0.90      1000
#
#     accuracy                           0.69     10000
#    macro avg       0.73      0.69      0.67     10000
# weighted avg       0.73      0.69      0.67     10000

# %% [markdown]
# ### Deep Neural Network

# %%
X_train, X_test, X_val = X_train.reshape(-1, 28, 28), X_test.reshape(-1, 28, 28), X_val.reshape(-1, 28, 28)

print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# (48000, 28, 28)
# (10000, 28, 28)
# (12000, 28, 28)

# %% [markdown]
# #### Declaring the hyperparameters

# %%
import time
dense_layers = [1,2]
layer_sizes = [32,64]

# %% [markdown]
# #### Training the Deep Neural Network

# %%
histories = {}
for dense_layer in dense_layers:
    for layer_size in layer_sizes:
            model_ckeckpoint = tf.keras.callbacks.ModelCheckpoint(filepath="{}-nodes-{}-dense.h5".format(layer_size, dense_layer), monitor="val_loss",verbose=1,save_best_only=True, save_weights_only=True)
            model = Sequential()
            model.add(Dense(layer_size, input_shape = X_train.shape[1:]))
            model.add(Activation("relu"))
            for l in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation("relu"))
            model.add(Flatten())
            model.add(Dense(10))
            model.add(Activation(activation="softmax"))
            model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics = ["accuracy"])
            history = model.fit(X_train,y_train,batch_size=2048,validation_data=(X_val, y_val),epochs=10, callbacks=[model_ckeckpoint])
            histories["{}-nodes-{}-dense".format(layer_size, dense_layer)] = history
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 1.8182 - accuracy: 0.4721
# Epoch 00001: val_loss improved from inf to 1.27010, saving model to 32-nodes-1-dense.h5
# 48000/48000 [==============================] - 7s 140us/sample - loss: 1.8090 - accuracy: 0.4760 - val_loss: 1.2701 - val_accuracy: 0.6827
# Epoch 2/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.9738 - accuracy: 0.7151
# Epoch 00002: val_loss improved from 1.27010 to 0.76248, saving model to 32-nodes-1-dense.h5
# 48000/48000 [==============================] - 2s 50us/sample - loss: 0.9697 - accuracy: 0.7158 - val_loss: 0.7625 - val_accuracy: 0.7466
# Epoch 3/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.6834 - accuracy: 0.7657
# Epoch 00003: val_loss improved from 0.76248 to 0.63057, saving model to 32-nodes-1-dense.h5
# 48000/48000 [==============================] - 2s 50us/sample - loss: 0.6825 - accuracy: 0.7661 - val_loss: 0.6306 - val_accuracy: 0.7797
# Epoch 4/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5881 - accuracy: 0.7944
# Epoch 00004: val_loss improved from 0.63057 to 0.56058, saving model to 32-nodes-1-dense.h5
# 48000/48000 [==============================] - 2s 52us/sample - loss: 0.5872 - accuracy: 0.7948 - val_loss: 0.5606 - val_accuracy: 0.8018
# Epoch 5/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5344 - accuracy: 0.8116
# Epoch 00005: val_loss improved from 0.56058 to 0.51795, saving model to 32-nodes-1-dense.h5
# 48000/48000 [==============================] - 3s 52us/sample - loss: 0.5334 - accuracy: 0.8118 - val_loss: 0.5179 - val_accuracy: 0.8152
# Epoch 6/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4994 - accuracy: 0.8269
# Epoch 00006: val_loss improved from 0.51795 to 0.49213, saving model to 32-nodes-1-dense.h5
# 48000/48000 [==============================] - 2s 50us/sample - loss: 0.4991 - accuracy: 0.8270 - val_loss: 0.4921 - val_accuracy: 0.8249
# Epoch 7/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4730 - accuracy: 0.8354
# Epoch 00007: val_loss improved from 0.49213 to 0.46800, saving model to 32-nodes-1-dense.h5
# 48000/48000 [==============================] - 3s 54us/sample - loss: 0.4726 - accuracy: 0.8356 - val_loss: 0.4680 - val_accuracy: 0.8357
# Epoch 8/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4540 - accuracy: 0.8422
# Epoch 00008: val_loss improved from 0.46800 to 0.45331, saving model to 32-nodes-1-dense.h5
# 48000/48000 [==============================] - 3s 54us/sample - loss: 0.4542 - accuracy: 0.8422 - val_loss: 0.4533 - val_accuracy: 0.8407
# Epoch 9/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4395 - accuracy: 0.8472
# Epoch 00009: val_loss improved from 0.45331 to 0.43823, saving model to 32-nodes-1-dense.h5
# 48000/48000 [==============================] - 2s 51us/sample - loss: 0.4394 - accuracy: 0.8473 - val_loss: 0.4382 - val_accuracy: 0.8468
# Epoch 10/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4264 - accuracy: 0.8506
# Epoch 00010: val_loss improved from 0.43823 to 0.42705, saving model to 32-nodes-1-dense.h5
# 48000/48000 [==============================] - 3s 54us/sample - loss: 0.4253 - accuracy: 0.8510 - val_loss: 0.4271 - val_accuracy: 0.8500
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 1.5866 - accuracy: 0.5562 ETA: 3s - loss: 1.8653
# Epoch 00001: val_loss improved from inf to 0.90324, saving model to 64-nodes-1-dense.h5
# 48000/48000 [==============================] - 8s 164us/sample - loss: 1.5757 - accuracy: 0.5585 - val_loss: 0.9032 - val_accuracy: 0.7137
# Epoch 2/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.7215 - accuracy: 0.7569
# Epoch 00002: val_loss improved from 0.90324 to 0.60928, saving model to 64-nodes-1-dense.h5
# 48000/48000 [==============================] - 4s 89us/sample - loss: 0.7193 - accuracy: 0.7573 - val_loss: 0.6093 - val_accuracy: 0.7864
# Epoch 3/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5532 - accuracy: 0.8063
# Epoch 00003: val_loss improved from 0.60928 to 0.51727, saving model to 64-nodes-1-dense.h5
# 48000/48000 [==============================] - 4s 86us/sample - loss: 0.5528 - accuracy: 0.8064 - val_loss: 0.5173 - val_accuracy: 0.8185
# Epoch 4/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4908 - accuracy: 0.8309
# Epoch 00004: val_loss improved from 0.51727 to 0.48080, saving model to 64-nodes-1-dense.h5
# 48000/48000 [==============================] - 4s 87us/sample - loss: 0.4897 - accuracy: 0.8312 - val_loss: 0.4808 - val_accuracy: 0.8314
# Epoch 5/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4568 - accuracy: 0.8424
# Epoch 00005: val_loss improved from 0.48080 to 0.45218, saving model to 64-nodes-1-dense.h5
# 48000/48000 [==============================] - 4s 74us/sample - loss: 0.4564 - accuracy: 0.8424 - val_loss: 0.4522 - val_accuracy: 0.8395
# Epoch 6/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4363 - accuracy: 0.8478
# Epoch 00006: val_loss improved from 0.45218 to 0.43644, saving model to 64-nodes-1-dense.h5
# 48000/48000 [==============================] - 3s 53us/sample - loss: 0.4365 - accuracy: 0.8476 - val_loss: 0.4364 - val_accuracy: 0.8497
# Epoch 7/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4214 - accuracy: 0.8532 ETA: 0s - loss: 0.4206 - accu - ETA: 0s - loss: 0.4214 - accuracy
# Epoch 00007: val_loss improved from 0.43644 to 0.42025, saving model to 64-nodes-1-dense.h5
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.4209 - accuracy: 0.8533 - val_loss: 0.4202 - val_accuracy: 0.8524
# Epoch 8/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4089 - accuracy: 0.8578
# Epoch 00008: val_loss improved from 0.42025 to 0.40742, saving model to 64-nodes-1-dense.h5
# 48000/48000 [==============================] - 4s 86us/sample - loss: 0.4088 - accuracy: 0.8578 - val_loss: 0.4074 - val_accuracy: 0.8556
# Epoch 9/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3975 - accuracy: 0.8606
# Epoch 00009: val_loss improved from 0.40742 to 0.39975, saving model to 64-nodes-1-dense.h5
# 48000/48000 [==============================] - 4s 81us/sample - loss: 0.3978 - accuracy: 0.8605 - val_loss: 0.3998 - val_accuracy: 0.8559
# Epoch 10/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3864 - accuracy: 0.8647
# Epoch 00010: val_loss improved from 0.39975 to 0.39519, saving model to 64-nodes-1-dense.h5
# 48000/48000 [==============================] - 4s 79us/sample - loss: 0.3869 - accuracy: 0.8643 - val_loss: 0.3952 - val_accuracy: 0.8610
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 1.9390 - accuracy: 0.3945
# Epoch 00001: val_loss improved from inf to 1.40267, saving model to 32-nodes-2-dense.h5
# 48000/48000 [==============================] - 6s 123us/sample - loss: 1.9299 - accuracy: 0.3985 - val_loss: 1.4027 - val_accuracy: 0.6017
# Epoch 2/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 1.0405 - accuracy: 0.6748
# Epoch 00002: val_loss improved from 1.40267 to 0.78639, saving model to 32-nodes-2-dense.h5
# 48000/48000 [==============================] - 3s 63us/sample - loss: 1.0358 - accuracy: 0.6759 - val_loss: 0.7864 - val_accuracy: 0.7294
# Epoch 3/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.6939 - accuracy: 0.7577
# Epoch 00003: val_loss improved from 0.78639 to 0.63602, saving model to 32-nodes-2-dense.h5
# 48000/48000 [==============================] - 3s 63us/sample - loss: 0.6929 - accuracy: 0.7581 - val_loss: 0.6360 - val_accuracy: 0.7730
# Epoch 4/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5943 - accuracy: 0.7886
# Epoch 00004: val_loss improved from 0.63602 to 0.56101, saving model to 32-nodes-2-dense.h5
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.5941 - accuracy: 0.7886 - val_loss: 0.5610 - val_accuracy: 0.7997
# Epoch 5/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5380 - accuracy: 0.8097
# Epoch 00005: val_loss improved from 0.56101 to 0.52149, saving model to 32-nodes-2-dense.h5
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.5378 - accuracy: 0.8097 - val_loss: 0.5215 - val_accuracy: 0.8166
# Epoch 6/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5029 - accuracy: 0.8230
# Epoch 00006: val_loss improved from 0.52149 to 0.49809, saving model to 32-nodes-2-dense.h5
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.5024 - accuracy: 0.8235 - val_loss: 0.4981 - val_accuracy: 0.8227
# Epoch 7/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4809 - accuracy: 0.8308
# Epoch 00007: val_loss improved from 0.49809 to 0.48259, saving model to 32-nodes-2-dense.h5
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.4797 - accuracy: 0.8311 - val_loss: 0.4826 - val_accuracy: 0.8273
# Epoch 8/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4592 - accuracy: 0.8390 ETA: 0s - loss: 0.4612
# Epoch 00008: val_loss improved from 0.48259 to 0.45558, saving model to 32-nodes-2-dense.h5
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.4598 - accuracy: 0.8390 - val_loss: 0.4556 - val_accuracy: 0.8400
# Epoch 9/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4428 - accuracy: 0.8458
# Epoch 00009: val_loss improved from 0.45558 to 0.44185, saving model to 32-nodes-2-dense.h5
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.4429 - accuracy: 0.8455 - val_loss: 0.4418 - val_accuracy: 0.8443
# Epoch 10/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4314 - accuracy: 0.8498
# Epoch 00010: val_loss improved from 0.44185 to 0.43031, saving model to 32-nodes-2-dense.h5
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.4319 - accuracy: 0.8495 - val_loss: 0.4303 - val_accuracy: 0.8493
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 1.6181 - accuracy: 0.5476
# Epoch 00001: val_loss improved from inf to 0.87763, saving model to 64-nodes-2-dense.h5
# 48000/48000 [==============================] - 8s 160us/sample - loss: 1.6047 - accuracy: 0.5500 - val_loss: 0.8776 - val_accuracy: 0.7038
# Epoch 2/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.7134 - accuracy: 0.7518
# Epoch 00002: val_loss improved from 0.87763 to 0.59892, saving model to 64-nodes-2-dense.h5
# 48000/48000 [==============================] - 5s 113us/sample - loss: 0.7118 - accuracy: 0.7522 - val_loss: 0.5989 - val_accuracy: 0.7887
# Epoch 3/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5434 - accuracy: 0.8112
# Epoch 00003: val_loss improved from 0.59892 to 0.50115, saving model to 64-nodes-2-dense.h5
# 48000/48000 [==============================] - 5s 106us/sample - loss: 0.5430 - accuracy: 0.8110 - val_loss: 0.5011 - val_accuracy: 0.8234
# Epoch 4/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4779 - accuracy: 0.8343
# Epoch 00004: val_loss improved from 0.50115 to 0.45450, saving model to 64-nodes-2-dense.h5
# 48000/48000 [==============================] - 5s 113us/sample - loss: 0.4769 - accuracy: 0.8348 - val_loss: 0.4545 - val_accuracy: 0.8378
# Epoch 5/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4446 - accuracy: 0.8447
# Epoch 00005: val_loss improved from 0.45450 to 0.42615, saving model to 64-nodes-2-dense.h5
# 48000/48000 [==============================] - 5s 110us/sample - loss: 0.4441 - accuracy: 0.8450 - val_loss: 0.4262 - val_accuracy: 0.8497
# Epoch 6/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4181 - accuracy: 0.8547
# Epoch 00006: val_loss improved from 0.42615 to 0.41353, saving model to 64-nodes-2-dense.h5
# 48000/48000 [==============================] - 5s 114us/sample - loss: 0.4175 - accuracy: 0.8551 - val_loss: 0.4135 - val_accuracy: 0.8528
# Epoch 7/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4012 - accuracy: 0.8597
# Epoch 00007: val_loss improved from 0.41353 to 0.40242, saving model to 64-nodes-2-dense.h5
# 48000/48000 [==============================] - 5s 113us/sample - loss: 0.4014 - accuracy: 0.8597 - val_loss: 0.4024 - val_accuracy: 0.8558
# Epoch 8/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3886 - accuracy: 0.8637
# Epoch 00008: val_loss improved from 0.40242 to 0.38623, saving model to 64-nodes-2-dense.h5
# 48000/48000 [==============================] - 5s 112us/sample - loss: 0.3884 - accuracy: 0.8637 - val_loss: 0.3862 - val_accuracy: 0.8603
# Epoch 9/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3767 - accuracy: 0.8689
# Epoch 00009: val_loss improved from 0.38623 to 0.38549, saving model to 64-nodes-2-dense.h5
# 48000/48000 [==============================] - 5s 107us/sample - loss: 0.3764 - accuracy: 0.8691 - val_loss: 0.3855 - val_accuracy: 0.8613
# Epoch 10/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3676 - accuracy: 0.8717
# Epoch 00010: val_loss improved from 0.38549 to 0.37278, saving model to 64-nodes-2-dense.h5
# 48000/48000 [==============================] - 5s 111us/sample - loss: 0.3677 - accuracy: 0.8716 - val_loss: 0.3728 - val_accuracy: 0.8668

# %% [markdown]
# #### Visualizing the Training Loss, Validation Loss, Training Accuracy, Validation Accuracy

# %%
def plot_histories(history, key):    
    plt.subplot(121)
    g = plt.plot(history.epoch, history.history["loss"], label=key, marker='o')
    plt.plot(history.epoch, history.history["val_loss"], "--", marker='o', c= g[0].get_color())
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.suptitle("Training and Validation Loss")
    plt.grid(True)
    plt.legend()

    plt.subplot(122)
    g = plt.plot(history.epoch, history.history["accuracy"], label=key, marker='o')
    plt.plot(history.epoch, history.history["val_accuracy"], "--", marker='o', c= g[0].get_color())
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.suptitle("Training and Validation Accuracy")
    plt.grid(True)
    plt.legend()

# %%
key = list(histories.keys())
plt.figure(figsize=(25,10))
for i in key:
    plot_histories(histories[i],i)

# %% [markdown]
# #### Choosing the best model

# %%
max_val_accuracy = 0
model_name = None
for i in key:
    if histories[i].history["val_accuracy"][-1] > max_val_accuracy:
        max_val_acc = histories[i].history["val_accuracy"][-1]
        model_name = i

# %%
print(f"The best hyperparameters are: {model_name}")
# Out:
# The best hyperparameters are: 64-nodes-2-dense

# %%
model.load_weights(f"{model_name}.h5")

# %% [markdown]
# #### Loading the Test Data

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=0, batch_size=1024)

# %%
for name, value in zip(model.metrics_names, (loss, accuracy)):
    print(name, ":", value)
# Out:
# loss : 0.4026598168849945
# accuracy : 0.8556

# %%
pred = model.predict(X_test)

# %%
predictions = np.argmax(pred, axis=1)

# %% [markdown]
# #### Plotting the Predictions

# %%
num_rows = 4
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(20, 15))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, pred[i], y_test, X_test.reshape(-1, 28, 28))
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, pred[i], y_test)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Classification Accuracy

# %%
print(f"The accuracy of the model is: {accuracy_score(predictions, y_test)*100}%")
# Out:
# The accuracy of the model is: 85.56%

# %% [markdown]
# #### Confusion Matrix

# %%
plt.figure(figsize=(10,10))
cm = confusion_matrix(y_test, predictions)
sns.heatmap(cm, center=0, linewidth=1, fmt="d", annot=True,cmap="RdBu")

# %% [markdown]
# #### Calculating the value of Precision, Recall, Accuracy and F1 score

# %%
print(classification_report(y_test, predictions, labels=np.arange(0,10)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.81      1000
#            1       0.98      0.97      0.97      1000
#            2       0.75      0.77      0.76      1000
#            3       0.84      0.87      0.86      1000
#            4       0.74      0.81      0.77      1000
#            5       0.96      0.91      0.94      1000
#            6       0.69      0.57      0.62      1000
#            7       0.91      0.94      0.92      1000
#            8       0.92      0.97      0.95      1000
#            9       0.93      0.95      0.94      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.85      0.86      0.85     10000
# weighted avg       0.85      0.86      0.85     10000

# %% [markdown]
# ### Convolutional Neural Network

# %%
X_train, X_test, X_val = X_train.reshape(X_train.shape + (1,)), X_test.reshape(X_test.shape + (1,)), X_val.reshape(X_val.shape + (1,))

print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# (48000, 28, 28, 1)
# (10000, 28, 28, 1)
# (12000, 28, 28, 1)

# %% [markdown]
# #### Declaring the hyperparameters

# %%
import time
dense_layers = [1,2]
layer_sizes = [32,64]
conv_layers = [1,2]

# %% [markdown]
# #### Training the Deep Neural Network

# %%
histories = {}
for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            model_ckeckpoint = tf.keras.callbacks.ModelCheckpoint(filepath="{}-nodes-{}-dense-{}-conv.h5".format(layer_size, dense_layer, conv_layer), monitor="val_loss",verbose=1,save_best_only=True, save_weights_only=True)
            model = Sequential()
            model.add(Conv2D(layer_size, (3,3), input_shape = X_train.shape[1:]))
            model.add(Activation("relu"))
            model.add(MaxPool2D(pool_size=(2,2)))
            for l in range(conv_layer-1):
                model.add(Conv2D(layer_size, (3,3), input_shape = X_train.shape[1:]))
                model.add(Activation("relu"))
                model.add(MaxPool2D(pool_size=(2,2)))
            for l in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation("relu"))
            model.add(Flatten())
            model.add(Dense(10))
            model.add(Activation(activation="softmax"))
            model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics = ["accuracy"])
            history = model.fit(X_train, y_train, batch_size=2048, validation_data=(X_val, y_val), callbacks=[model_ckeckpoint], epochs=10)
            histories["{}-nodes-{}-dense-{}-conv".format(layer_size, dense_layer,conv_layer)] = history
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 1.4441 - accuracy: 0.5845
# Epoch 00001: val_loss improved from inf to 0.79009, saving model to 32-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 28s 592us/sample - loss: 1.4322 - accuracy: 0.5875 - val_loss: 0.7901 - val_accuracy: 0.7333
# Epoch 2/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.6751 - accuracy: 0.7656
# Epoch 00002: val_loss improved from 0.79009 to 0.60571, saving model to 32-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 25s 523us/sample - loss: 0.6739 - accuracy: 0.7659 - val_loss: 0.6057 - val_accuracy: 0.7838
# Epoch 3/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5575 - accuracy: 0.8048
# Epoch 00003: val_loss improved from 0.60571 to 0.52326, saving model to 32-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 26s 537us/sample - loss: 0.5564 - accuracy: 0.8054 - val_loss: 0.5233 - val_accuracy: 0.8173
# Epoch 4/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4962 - accuracy: 0.8292
# Epoch 00004: val_loss improved from 0.52326 to 0.48002, saving model to 32-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 25s 531us/sample - loss: 0.4962 - accuracy: 0.8295 - val_loss: 0.4800 - val_accuracy: 0.8315
# Epoch 5/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4569 - accuracy: 0.8419
# Epoch 00005: val_loss improved from 0.48002 to 0.44154, saving model to 32-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 25s 525us/sample - loss: 0.4574 - accuracy: 0.8419 - val_loss: 0.4415 - val_accuracy: 0.8453
# Epoch 6/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4301 - accuracy: 0.8506
# Epoch 00006: val_loss improved from 0.44154 to 0.42225, saving model to 32-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 25s 520us/sample - loss: 0.4294 - accuracy: 0.8508 - val_loss: 0.4223 - val_accuracy: 0.8521
# Epoch 7/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4046 - accuracy: 0.8596
# Epoch 00007: val_loss improved from 0.42225 to 0.39688, saving model to 32-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 25s 526us/sample - loss: 0.4053 - accuracy: 0.8593 - val_loss: 0.3969 - val_accuracy: 0.8608
# Epoch 8/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3862 - accuracy: 0.8657
# Epoch 00008: val_loss improved from 0.39688 to 0.38054, saving model to 32-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 26s 534us/sample - loss: 0.3870 - accuracy: 0.8655 - val_loss: 0.3805 - val_accuracy: 0.8637
# Epoch 9/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3725 - accuracy: 0.8704
# Epoch 00009: val_loss improved from 0.38054 to 0.36850, saving model to 32-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 26s 535us/sample - loss: 0.3720 - accuracy: 0.8706 - val_loss: 0.3685 - val_accuracy: 0.8698
# Epoch 10/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3600 - accuracy: 0.8748
# Epoch 00010: val_loss improved from 0.36850 to 0.35542, saving model to 32-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 25s 531us/sample - loss: 0.3599 - accuracy: 0.8750 - val_loss: 0.3554 - val_accuracy: 0.8725
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 1.8854 - accuracy: 0.3891
# Epoch 00001: val_loss improved from inf to 1.17529, saving model to 32-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 36s 758us/sample - loss: 1.8726 - accuracy: 0.3926 - val_loss: 1.1753 - val_accuracy: 0.5818
# Epoch 2/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.9477 - accuracy: 0.6505
# Epoch 00002: val_loss improved from 1.17529 to 0.80573, saving model to 32-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 34s 708us/sample - loss: 0.9454 - accuracy: 0.6517 - val_loss: 0.8057 - val_accuracy: 0.7118
# Epoch 3/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.7450 - accuracy: 0.7255
# Epoch 00003: val_loss improved from 0.80573 to 0.69734, saving model to 32-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 34s 712us/sample - loss: 0.7441 - accuracy: 0.7259 - val_loss: 0.6973 - val_accuracy: 0.7437
# Epoch 4/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.6626 - accuracy: 0.7554
# Epoch 00004: val_loss improved from 0.69734 to 0.62361, saving model to 32-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 34s 704us/sample - loss: 0.6615 - accuracy: 0.7559 - val_loss: 0.6236 - val_accuracy: 0.7617
# Epoch 5/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.6026 - accuracy: 0.7779
# Epoch 00005: val_loss improved from 0.62361 to 0.57632, saving model to 32-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 34s 711us/sample - loss: 0.6022 - accuracy: 0.7783 - val_loss: 0.5763 - val_accuracy: 0.7862
# Epoch 6/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5582 - accuracy: 0.7961
# Epoch 00006: val_loss improved from 0.57632 to 0.52956, saving model to 32-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 33s 683us/sample - loss: 0.5575 - accuracy: 0.7964 - val_loss: 0.5296 - val_accuracy: 0.8077
# Epoch 7/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5246 - accuracy: 0.8099
# Epoch 00007: val_loss improved from 0.52956 to 0.50958, saving model to 32-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 37s 769us/sample - loss: 0.5239 - accuracy: 0.8100 - val_loss: 0.5096 - val_accuracy: 0.8123
# Epoch 8/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4944 - accuracy: 0.8225
# Epoch 00008: val_loss improved from 0.50958 to 0.47786, saving model to 32-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 36s 749us/sample - loss: 0.4943 - accuracy: 0.8224 - val_loss: 0.4779 - val_accuracy: 0.8250
# Epoch 9/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4699 - accuracy: 0.8323
# Epoch 00009: val_loss improved from 0.47786 to 0.46152, saving model to 32-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 37s 772us/sample - loss: 0.4699 - accuracy: 0.8322 - val_loss: 0.4615 - val_accuracy: 0.8298
# Epoch 10/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4527 - accuracy: 0.8402
# Epoch 00010: val_loss improved from 0.46152 to 0.43855, saving model to 32-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 37s 776us/sample - loss: 0.4529 - accuracy: 0.8404 - val_loss: 0.4386 - val_accuracy: 0.8417
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 47104/48000 [============================>.] - ETA: 2s - loss: 1.3610 - accuracy: 0.6024
# Epoch 00001: val_loss improved from inf to 0.70778, saving model to 64-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 162s 3ms/sample - loss: 1.3493 - accuracy: 0.6052 - val_loss: 0.7078 - val_accuracy: 0.7561
# Epoch 2/10
# 47104/48000 [============================>.] - ETA: 3s - loss: 0.6196 - accuracy: 0.7821
# Epoch 00002: val_loss improved from 0.70778 to 0.54502, saving model to 64-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 211s 4ms/sample - loss: 0.6186 - accuracy: 0.7825 - val_loss: 0.5450 - val_accuracy: 0.8067
# Epoch 3/10
# 47104/48000 [============================>.] - ETA: 3s - loss: 0.4961 - accuracy: 0.8301
# Epoch 00003: val_loss improved from 0.54502 to 0.46310, saving model to 64-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 212s 4ms/sample - loss: 0.4956 - accuracy: 0.8303 - val_loss: 0.4631 - val_accuracy: 0.8375
# Epoch 4/10
# 47104/48000 [============================>.] - ETA: 2s - loss: 0.4383 - accuracy: 0.8496
# Epoch 00004: val_loss improved from 0.46310 to 0.42245, saving model to 64-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 158s 3ms/sample - loss: 0.4381 - accuracy: 0.8496 - val_loss: 0.4224 - val_accuracy: 0.8500
# Epoch 5/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4029 - accuracy: 0.8615
# Epoch 00005: val_loss improved from 0.42245 to 0.39084, saving model to 64-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 53s 1ms/sample - loss: 0.4024 - accuracy: 0.8618 - val_loss: 0.3908 - val_accuracy: 0.8602
# Epoch 6/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3785 - accuracy: 0.8691
# Epoch 00006: val_loss improved from 0.39084 to 0.37294, saving model to 64-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 54s 1ms/sample - loss: 0.3782 - accuracy: 0.8693 - val_loss: 0.3729 - val_accuracy: 0.8684
# Epoch 7/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3600 - accuracy: 0.8752
# Epoch 00007: val_loss improved from 0.37294 to 0.35411, saving model to 64-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 54s 1ms/sample - loss: 0.3598 - accuracy: 0.8751 - val_loss: 0.3541 - val_accuracy: 0.8739
# Epoch 8/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3432 - accuracy: 0.8813
# Epoch 00008: val_loss improved from 0.35411 to 0.34219, saving model to 64-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 54s 1ms/sample - loss: 0.3433 - accuracy: 0.8811 - val_loss: 0.3422 - val_accuracy: 0.8783
# Epoch 9/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3334 - accuracy: 0.8848
# Epoch 00009: val_loss improved from 0.34219 to 0.34129, saving model to 64-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 54s 1ms/sample - loss: 0.3336 - accuracy: 0.8848 - val_loss: 0.3413 - val_accuracy: 0.8785
# Epoch 10/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3260 - accuracy: 0.8867
# Epoch 00010: val_loss improved from 0.34129 to 0.33485, saving model to 64-nodes-1-dense-1-conv.h5
# 48000/48000 [==============================] - 54s 1ms/sample - loss: 0.3251 - accuracy: 0.8871 - val_loss: 0.3349 - val_accuracy: 0.8822
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 47104/48000 [============================>.] - ETA: 1s - loss: 1.5738 - accuracy: 0.5005
# Epoch 00001: val_loss improved from inf to 0.87723, saving model to 64-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 60s 1ms/sample - loss: 1.5621 - accuracy: 0.5032 - val_loss: 0.8772 - val_accuracy: 0.6784
# Epoch 2/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.7610 - accuracy: 0.7243
# Epoch 00002: val_loss improved from 0.87723 to 0.65873, saving model to 64-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 43s 887us/sample - loss: 0.7590 - accuracy: 0.7250 - val_loss: 0.6587 - val_accuracy: 0.7541
# Epoch 3/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.6107 - accuracy: 0.7764
# Epoch 00003: val_loss improved from 0.65873 to 0.55944, saving model to 64-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 42s 869us/sample - loss: 0.6107 - accuracy: 0.7766 - val_loss: 0.5594 - val_accuracy: 0.7883
# Epoch 4/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5324 - accuracy: 0.8055
# Epoch 00004: val_loss improved from 0.55944 to 0.51685, saving model to 64-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 42s 870us/sample - loss: 0.5321 - accuracy: 0.8058 - val_loss: 0.5169 - val_accuracy: 0.8112
# Epoch 5/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4858 - accuracy: 0.8264
# Epoch 00005: val_loss improved from 0.51685 to 0.48002, saving model to 64-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 42s 880us/sample - loss: 0.4851 - accuracy: 0.8267 - val_loss: 0.4800 - val_accuracy: 0.8191
# Epoch 6/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4556 - accuracy: 0.8374
# Epoch 00006: val_loss improved from 0.48002 to 0.44387, saving model to 64-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 41s 864us/sample - loss: 0.4549 - accuracy: 0.8374 - val_loss: 0.4439 - val_accuracy: 0.8377
# Epoch 7/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4277 - accuracy: 0.8480
# Epoch 00007: val_loss improved from 0.44387 to 0.42841, saving model to 64-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 42s 871us/sample - loss: 0.4275 - accuracy: 0.8479 - val_loss: 0.4284 - val_accuracy: 0.8441
# Epoch 8/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4114 - accuracy: 0.8552
# Epoch 00008: val_loss improved from 0.42841 to 0.41708, saving model to 64-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 42s 874us/sample - loss: 0.4108 - accuracy: 0.8555 - val_loss: 0.4171 - val_accuracy: 0.8469
# Epoch 9/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3981 - accuracy: 0.8609
# Epoch 00009: val_loss improved from 0.41708 to 0.39598, saving model to 64-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 42s 866us/sample - loss: 0.3973 - accuracy: 0.8612 - val_loss: 0.3960 - val_accuracy: 0.8566
# Epoch 10/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3831 - accuracy: 0.8660
# Epoch 00010: val_loss improved from 0.39598 to 0.37602, saving model to 64-nodes-1-dense-2-conv.h5
# 48000/48000 [==============================] - 42s 871us/sample - loss: 0.3823 - accuracy: 0.8663 - val_loss: 0.3760 - val_accuracy: 0.8633
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 1.4048 - accuracy: 0.5616
# Epoch 00001: val_loss improved from inf to 0.80029, saving model to 32-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 17s 350us/sample - loss: 1.3935 - accuracy: 0.5648 - val_loss: 0.8003 - val_accuracy: 0.7057
# Epoch 2/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.6933 - accuracy: 0.7553
# Epoch 00002: val_loss improved from 0.80029 to 0.62071, saving model to 32-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 16s 330us/sample - loss: 0.6919 - accuracy: 0.7555 - val_loss: 0.6207 - val_accuracy: 0.7800
# Epoch 3/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5711 - accuracy: 0.8001
# Epoch 00003: val_loss improved from 0.62071 to 0.53311, saving model to 32-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 16s 333us/sample - loss: 0.5710 - accuracy: 0.8001 - val_loss: 0.5331 - val_accuracy: 0.8122
# Epoch 4/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5012 - accuracy: 0.8265
# Epoch 00004: val_loss improved from 0.53311 to 0.47535, saving model to 32-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 16s 330us/sample - loss: 0.5007 - accuracy: 0.8265 - val_loss: 0.4754 - val_accuracy: 0.8325
# Epoch 5/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4539 - accuracy: 0.8400
# Epoch 00005: val_loss improved from 0.47535 to 0.43967, saving model to 32-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 16s 330us/sample - loss: 0.4533 - accuracy: 0.8406 - val_loss: 0.4397 - val_accuracy: 0.8481
# Epoch 6/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4158 - accuracy: 0.8554
# Epoch 00006: val_loss improved from 0.43967 to 0.40487, saving model to 32-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 16s 334us/sample - loss: 0.4161 - accuracy: 0.8553 - val_loss: 0.4049 - val_accuracy: 0.8560
# Epoch 7/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3934 - accuracy: 0.8634
# Epoch 00007: val_loss improved from 0.40487 to 0.38910, saving model to 32-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 16s 331us/sample - loss: 0.3927 - accuracy: 0.8639 - val_loss: 0.3891 - val_accuracy: 0.8636
# Epoch 8/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3721 - accuracy: 0.8709
# Epoch 00008: val_loss improved from 0.38910 to 0.36899, saving model to 32-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 16s 334us/sample - loss: 0.3721 - accuracy: 0.8705 - val_loss: 0.3690 - val_accuracy: 0.8706
# Epoch 9/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3575 - accuracy: 0.8745
# Epoch 00009: val_loss improved from 0.36899 to 0.36298, saving model to 32-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 16s 333us/sample - loss: 0.3578 - accuracy: 0.8745 - val_loss: 0.3630 - val_accuracy: 0.8710
# Epoch 10/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3505 - accuracy: 0.8763
# Epoch 00010: val_loss improved from 0.36298 to 0.35311, saving model to 32-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 16s 330us/sample - loss: 0.3510 - accuracy: 0.8762 - val_loss: 0.3531 - val_accuracy: 0.8728
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 1.9485 - accuracy: 0.4177
# Epoch 00001: val_loss improved from inf to 1.16884, saving model to 32-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 20s 422us/sample - loss: 1.9355 - accuracy: 0.4209 - val_loss: 1.1688 - val_accuracy: 0.6127
# Epoch 2/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.9051 - accuracy: 0.6778
# Epoch 00002: val_loss improved from 1.16884 to 0.75652, saving model to 32-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 19s 401us/sample - loss: 0.9036 - accuracy: 0.6780 - val_loss: 0.7565 - val_accuracy: 0.7247
# Epoch 3/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.6970 - accuracy: 0.7456
# Epoch 00003: val_loss improved from 0.75652 to 0.63916, saving model to 32-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 19s 406us/sample - loss: 0.6956 - accuracy: 0.7462 - val_loss: 0.6392 - val_accuracy: 0.7617
# Epoch 4/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.6091 - accuracy: 0.7752
# Epoch 00004: val_loss improved from 0.63916 to 0.57786, saving model to 32-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 19s 405us/sample - loss: 0.6076 - accuracy: 0.7755 - val_loss: 0.5779 - val_accuracy: 0.7794
# Epoch 5/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5577 - accuracy: 0.7940
# Epoch 00005: val_loss improved from 0.57786 to 0.53886, saving model to 32-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 21s 428us/sample - loss: 0.5586 - accuracy: 0.7935 - val_loss: 0.5389 - val_accuracy: 0.7958
# Epoch 6/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5224 - accuracy: 0.8094
# Epoch 00006: val_loss improved from 0.53886 to 0.50420, saving model to 32-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 21s 436us/sample - loss: 0.5224 - accuracy: 0.8094 - val_loss: 0.5042 - val_accuracy: 0.8111
# Epoch 7/10
# 47104/48000 [============================>.] - ETA: 1s - loss: 0.4911 - accuracy: 0.8228
# Epoch 00007: val_loss improved from 0.50420 to 0.47847, saving model to 32-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 69s 1ms/sample - loss: 0.4915 - accuracy: 0.8226 - val_loss: 0.4785 - val_accuracy: 0.8261
# Epoch 8/10
# 47104/48000 [============================>.] - ETA: 1s - loss: 0.4722 - accuracy: 0.8295
# Epoch 00008: val_loss improved from 0.47847 to 0.46360, saving model to 32-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 87s 2ms/sample - loss: 0.4715 - accuracy: 0.8299 - val_loss: 0.4636 - val_accuracy: 0.8317
# Epoch 9/10
# 47104/48000 [============================>.] - ETA: 1s - loss: 0.4550 - accuracy: 0.8366
# Epoch 00009: val_loss improved from 0.46360 to 0.44685, saving model to 32-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 87s 2ms/sample - loss: 0.4540 - accuracy: 0.8370 - val_loss: 0.4469 - val_accuracy: 0.8315
# Epoch 10/10
# 47104/48000 [============================>.] - ETA: 1s - loss: 0.4376 - accuracy: 0.8433
# Epoch 00010: val_loss improved from 0.44685 to 0.42919, saving model to 32-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 77s 2ms/sample - loss: 0.4376 - accuracy: 0.8433 - val_loss: 0.4292 - val_accuracy: 0.8415
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 1.2938 - accuracy: 0.6050
# Epoch 00001: val_loss improved from inf to 0.74715, saving model to 64-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 28s 579us/sample - loss: 1.2832 - accuracy: 0.6078 - val_loss: 0.7472 - val_accuracy: 0.7347
# Epoch 2/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.6371 - accuracy: 0.7778
# Epoch 00002: val_loss improved from 0.74715 to 0.57621, saving model to 64-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 32s 660us/sample - loss: 0.6362 - accuracy: 0.7780 - val_loss: 0.5762 - val_accuracy: 0.7960
# Epoch 3/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5172 - accuracy: 0.8199
# Epoch 00003: val_loss improved from 0.57621 to 0.48145, saving model to 64-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 32s 659us/sample - loss: 0.5165 - accuracy: 0.8204 - val_loss: 0.4815 - val_accuracy: 0.8295
# Epoch 4/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4510 - accuracy: 0.8431
# Epoch 00004: val_loss improved from 0.48145 to 0.42871, saving model to 64-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 32s 663us/sample - loss: 0.4509 - accuracy: 0.8433 - val_loss: 0.4287 - val_accuracy: 0.8480
# Epoch 5/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4138 - accuracy: 0.8562
# Epoch 00005: val_loss improved from 0.42871 to 0.40680, saving model to 64-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 32s 661us/sample - loss: 0.4141 - accuracy: 0.8561 - val_loss: 0.4068 - val_accuracy: 0.8545
# Epoch 6/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3879 - accuracy: 0.8649
# Epoch 00006: val_loss improved from 0.40680 to 0.37878, saving model to 64-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 32s 663us/sample - loss: 0.3876 - accuracy: 0.8648 - val_loss: 0.3788 - val_accuracy: 0.8648
# Epoch 7/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3730 - accuracy: 0.8694
# Epoch 00007: val_loss improved from 0.37878 to 0.36163, saving model to 64-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 32s 664us/sample - loss: 0.3718 - accuracy: 0.8695 - val_loss: 0.3616 - val_accuracy: 0.8715
# Epoch 8/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3523 - accuracy: 0.8770
# Epoch 00008: val_loss improved from 0.36163 to 0.35502, saving model to 64-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 33s 681us/sample - loss: 0.3519 - accuracy: 0.8772 - val_loss: 0.3550 - val_accuracy: 0.8732
# Epoch 9/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3422 - accuracy: 0.8802
# Epoch 00009: val_loss did not improve from 0.35502
# 48000/48000 [==============================] - 32s 665us/sample - loss: 0.3424 - accuracy: 0.8800 - val_loss: 0.3553 - val_accuracy: 0.8707
# Epoch 10/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3320 - accuracy: 0.8827
# Epoch 00010: val_loss improved from 0.35502 to 0.34392, saving model to 64-nodes-2-dense-1-conv.h5
# 48000/48000 [==============================] - 32s 662us/sample - loss: 0.3324 - accuracy: 0.8825 - val_loss: 0.3439 - val_accuracy: 0.8776
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 1.7496 - accuracy: 0.5054
# Epoch 00001: val_loss improved from inf to 0.84350, saving model to 64-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 43s 890us/sample - loss: 1.7341 - accuracy: 0.5085 - val_loss: 0.8435 - val_accuracy: 0.6893
# Epoch 2/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.7386 - accuracy: 0.7344
# Epoch 00002: val_loss improved from 0.84350 to 0.62757, saving model to 64-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 42s 871us/sample - loss: 0.7366 - accuracy: 0.7351 - val_loss: 0.6276 - val_accuracy: 0.7664
# Epoch 3/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5776 - accuracy: 0.7873
# Epoch 00003: val_loss improved from 0.62757 to 0.53322, saving model to 64-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 42s 868us/sample - loss: 0.5774 - accuracy: 0.7874 - val_loss: 0.5332 - val_accuracy: 0.8008
# Epoch 4/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5077 - accuracy: 0.8164
# Epoch 00004: val_loss improved from 0.53322 to 0.47495, saving model to 64-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 42s 881us/sample - loss: 0.5072 - accuracy: 0.8169 - val_loss: 0.4749 - val_accuracy: 0.8275
# Epoch 5/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4681 - accuracy: 0.8302
# Epoch 00005: val_loss improved from 0.47495 to 0.45348, saving model to 64-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 42s 871us/sample - loss: 0.4676 - accuracy: 0.8302 - val_loss: 0.4535 - val_accuracy: 0.8315
# Epoch 6/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4413 - accuracy: 0.8452
# Epoch 00006: val_loss improved from 0.45348 to 0.43128, saving model to 64-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 42s 876us/sample - loss: 0.4412 - accuracy: 0.8452 - val_loss: 0.4313 - val_accuracy: 0.8493
# Epoch 7/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4190 - accuracy: 0.8526
# Epoch 00007: val_loss improved from 0.43128 to 0.40829, saving model to 64-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 42s 876us/sample - loss: 0.4185 - accuracy: 0.8526 - val_loss: 0.4083 - val_accuracy: 0.8523
# Epoch 8/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3997 - accuracy: 0.8602
# Epoch 00008: val_loss improved from 0.40829 to 0.39268, saving model to 64-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 42s 869us/sample - loss: 0.4001 - accuracy: 0.8601 - val_loss: 0.3927 - val_accuracy: 0.8565
# Epoch 9/10
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.3846 - accuracy: 0.8652
# Epoch 00009: val_loss improved from 0.39268 to 0.38510, saving model to 64-nodes-2-dense-2-conv.h5
# 48000/48000 [==============================] - 42s 872us/sample - loss: 0.3844 - accuracy: 0.8651 - val_loss: 0.3851 - val_accuracy: 0.8616
# Epoch 10/10
# 22528/48000 [=============>................] - ETA: 21s - loss: 0.3746 - accuracy: 0.8698

# %%
key = list(histories.keys())
plt.figure(figsize=(25,10))
for i in key:
    plot_histories(histories[i],i)

# %% [markdown]
# #### Visualizing the Training Loss, Validation Loss, Training Accuracy, Validation Accuracy

# %%
max_val_accuracy = 0
model_name = None
for i in key:
    if histories[i].history["val_accuracy"][-1] > max_val_accuracy:
        max_val_acc = histories[i].history["val_accuracy"][-1]
        model_name = i

# %% [markdown]
# #### Choosing the best model

# %%
print(f"The best model hyperparameters is {model_name}")

# %%
model.load_weights(f"{model_name}.h5")

# %% [markdown]
# #### Loading the Test Data

# %%
loss, accuracy = model.evaluate(X_test, y_test, batch_size=1024, verbose=0)

# %%
for name, value in zip(model.metrics_names, (loss, accuracy)):
    print(name, ":", value)

# %%
pred = model.predict(X_test)

# %%
predictions = np.argmax(pred, axis=1)

# %% [markdown]
# #### Plotting the Predictions

# %%
num_rows = 4
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(20, 15))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, pred[i], y_test, X_test.reshape(-1, 28, 28))
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, pred[i], y_test)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Classification Accuracy

# %%
print(f"The accuracy of the model is: {accuracy_score(predictions, y_test)*100}%")

# %% [markdown]
# #### Confusion Matrix

# %%
plt.figure(figsize=(10,10))
cm = confusion_matrix(y_test, predictions)
sns.heatmap(cm, center=0, linewidth=1, fmt="d", annot=True,cmap="RdBu")

# %% [markdown]
# #### Calculating the value of Precision, Recall, Accuracy and F1 score

# %%
print(classification_report(y_test, predictions, labels=np.arange(0,10)))
